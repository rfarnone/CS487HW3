# %%
# Mount the Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install the ART library (provides adversarial attacks)
# !pip install adversarial-robustness-toolbox
# Out:
# Collecting adversarial-robustness-toolbox
#   Downloading adversarial_robustness_toolbox-1.19.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from adversarial-robustness-toolbox) (1.26.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from adversarial-robustness-toolbox) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.11/dist-packages (from adversarial-robustness-toolbox) (1.6.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from adversarial-robustness-toolbox) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from adversarial-robustness-toolbox) (75.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from adversarial-robustness-toolbox) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.2->adversarial-robustness-toolbox) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.2->adversarial-robustness-toolbox) (3.5.0)
# Downloading adversarial_robustness_toolbox-1.19.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 69.8 MB/s eta 0:00:00
# Installing collected packages: adversarial-robustness-toolbox
# Successfully installed adversarial-robustness-toolbox-1.19.1

# %%
# Import libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle
import pandas as pd
import os
from os import listdir
import cv2
import natsort
from sklearn.model_selection import train_test_split

# Note: in this assignment we will be using the TensorFlowV2 classifier in ART
# It does not require to disable eager execution

# Print the version of tensorflow
print("TensorFlow version:{}".format(tf.__version__))
# Out:
# TensorFlow version:2.18.0

# %%
# Download the dataset
# !wget https://www.webpages.uidaho.edu/vakanski/Codes_Data/GTSRB_dataset.zip
# Out:
# --2025-02-23 22:49:24--  https://www.webpages.uidaho.edu/vakanski/Codes_Data/GTSRB_dataset.zip
# Resolving www.webpages.uidaho.edu (www.webpages.uidaho.edu)... 129.101.105.230
# Connecting to www.webpages.uidaho.edu (www.webpages.uidaho.edu)|129.101.105.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 123643346 (118M) [application/x-zip-compressed]
# Saving to: ‘GTSRB_dataset.zip’
#
# GTSRB_dataset.zip   100%[===================>] 117.92M  17.7MB/s    in 8.8s
#
# 2025-02-23 22:49:34 (13.5 MB/s) - ‘GTSRB_dataset.zip’ saved [123643346/123643346]

# %%
# Uncompress the dataset
# !unzip -uq 'GTSRB_dataset.zip' -d 'sample_data/'

# %%
# Path to the directory containing the dataset
DATA_DIR = 'sample_data/GTSRB_dataset/'

# %%
# Function for loading the dataset
# Code from advml-traffic-sign (https://github.com/inspire-group/advml-traffic-sign)
def load_dataset_GTSRB(n_channel=3, train_file_name=None):
    """
    Load GTSRB data as a (datasize) x (channels) x (height) x (width) numpy
    matrix. Each pixel is rescaled to the range [0,1].
    """

    def load_pickled_data(file, columns):
        """
        Loads pickled training and test data.

        Parameters
        ----------
        file    : string
                          Name of the pickle file.
        columns : list of strings
                          List of columns in pickled data we're interested in.

        Returns
        -------
        A tuple of datasets for given columns.
        """

        with open(file, mode='rb') as f:
            dataset = pickle.load(f)
        return tuple(map(lambda c: dataset[c], columns))

    def preprocess(x, n_channel):
        """
        Preprocess dataset: turn images into grayscale if specified,
        reshape array to appropriate shape for NN model
        """

        if n_channel == 3:
            # Scale features to be in [0, 1]
            x = x.astype(np.float32)
        else:
            # Convert to grayscale, e.g. single Y channel
            x = 0.299 * x[:, :, :, 0] + 0.587 * x[:, :, :, 1] + \
                0.114 * x[:, :, :, 2]
            # Scale features to be in [0, 1]
            x = x.astype(np.float32)
            x = x[:, :, :, np.newaxis]
        return x

    # Load pickle dataset
    if train_file_name is None:
        x_train, y_train = load_pickled_data(DATA_DIR + 'train.p', ['features', 'labels'])
        x_val, y_val = load_pickled_data(DATA_DIR + 'valid.p', ['features', 'labels'])
        x_test, y_test = load_pickled_data(DATA_DIR + 'test.p', ['features', 'labels'])

    # Preprocess loaded data
    x_train = preprocess(x_train, n_channel)
    x_val = preprocess(x_val, n_channel)
    x_test = preprocess(x_test, n_channel)

    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
# Load the images and labels
imgs_train, labels_train, imgs_val, labels_val, imgs_test, labels_test = load_dataset_GTSRB()

# %%
# Display the shapes of train, validation, and test datasets
print('Images train shape: {} - Labels train shape: {}'.format(imgs_train.shape, labels_train.shape))
print('Images validation shape: {} - Labels validation shape: {}'.format(imgs_val.shape, labels_val.shape))
print('Images test shape: {} - Labels test shape: {}'.format(imgs_test.shape, labels_test.shape))

# Display the range of images
print('\nMax pixel value', np.max(imgs_train))
print('Min pixel value', np.min(imgs_train))
print('Average pixel value', np.mean(imgs_train))
print('Data type', imgs_train[0].dtype)
# Out:
# Images train shape: (34799, 32, 32, 3) - Labels train shape: (34799,)
# Images validation shape: (4410, 32, 32, 3) - Labels validation shape: (4410,)
# Images test shape: (12630, 32, 32, 3) - Labels test shape: (12630,)
#
# Max pixel value 255.0
# Min pixel value 0.0
# Average pixel value 82.67778
# Data type float32

# %%
# Read the sign names
label_names = pd.read_csv('sample_data/GTSRB_dataset/signnames.csv').values[:, 1]

# Plot a few images to check if the data makes sense (note that the quality of some of the images is pretty low)
plt.figure(figsize=(10, 8))
for n in range(9):
    i = np.random.randint(0, len(imgs_train), 1)
    ax = plt.subplot(3, 3, n+1)
    plt.imshow(imgs_train[i[0]].astype(np.uint8))
    plt.title('Label:' + str(label_names[labels_train[i[0]]]))
    plt.axis('off')

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import ResNet50

import datetime
now = datetime.datetime.now

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# Add a fully-connected layer
x = Dense(2048, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.25)(x)
# Add a softmax layer with 43 classes
predictions = Dense(43, activation='softmax')(x)

# The model
model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
model.compile(optimizer=Adam(learning_rate=1e-4), loss='sparse_categorical_crossentropy', metrics = ['accuracy'])

# fit model
callbacks = [EarlyStopping(monitor='val_loss', patience=3)]

t = now()
history = model.fit(imgs_train, labels_train, epochs=100, batch_size=64,
                     validation_data=[imgs_val, labels_val], verbose=1, callbacks=callbacks)
print('\nTraining time: %s' % (now() - t))
# Out:
# Epoch 1/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 100s 85ms/step - accuracy: 0.4263 - loss: 2.2101 - val_accuracy: 0.7533 - val_loss: 0.9640
# Epoch 2/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - accuracy: 0.9416 - loss: 0.1909 - val_accuracy: 0.8238 - val_loss: 0.8980
# Epoch 3/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - accuracy: 0.9804 - loss: 0.0665 - val_accuracy: 0.8351 - val_loss: 0.8880
# Epoch 4/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9864 - loss: 0.0470 - val_accuracy: 0.8673 - val_loss: 0.6758
# Epoch 5/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9874 - loss: 0.0453 - val_accuracy: 0.8717 - val_loss: 0.6722
# Epoch 6/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9916 - loss: 0.0278 - val_accuracy: 0.8764 - val_loss: 0.6639
# Epoch 7/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9918 - loss: 0.0310 - val_accuracy: 0.8889 - val_loss: 0.6057
# Epoch 8/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9929 - loss: 0.0265 - val_accuracy: 0.9016 - val_loss: 0.5200
# Epoch 9/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9916 - loss: 0.0339 - val_accuracy: 0.9150 - val_loss: 0.4489
# Epoch 10/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9939 - loss: 0.0223 - val_accuracy: 0.9227 - val_loss: 0.4303
# Epoch 11/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9949 - loss: 0.0208 - val_accuracy: 0.8973 - val_loss: 0.6674
# Epoch 12/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9930 - loss: 0.0344 - val_accuracy: 0.9315 - val_loss: 0.3809
# Epoch 13/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9936 - loss: 0.0324 - val_accuracy: 0.9122 - val_loss: 0.5440
# Epoch 14/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9926 - loss: 0.0377 - val_accuracy: 0.9367 - val_loss: 0.3130
# Epoch 15/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9936 - loss: 0.0338 - val_accuracy: 0.9370 - val_loss: 0.3556
# Epoch 16/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9956 - loss: 0.0258 - val_accuracy: 0.9145 - val_loss: 0.4154
# Epoch 17/100
# 544/544 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.9974 - loss: 0.0119 - val_accuracy: 0.9336 - val_loss: 0.4522
#
# Training time: 0:07:04.076483

# %%
# Plot the loss and accuracy
train_loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochsn = np.arange(1, len(train_loss)+1,1)
plt.plot(epochsn,train_loss, 'b', label='Training Loss')
plt.plot(epochsn,val_loss, 'r', label='Validation Loss')
plt.grid(color='gray', linestyle='--')
plt.legend()
plt.title('LOSS')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.figure()
plt.plot(epochsn, acc, 'b', label='Training Accuracy')
plt.plot(epochsn, val_acc, 'r', label='Validation Accuracy')
plt.grid(color='gray', linestyle='--')
plt.legend()
plt.title('ACCURACY')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
# Evaluate on test images
evals_test = model.evaluate(imgs_test, labels_test)
print("Classification Accuracy: ", evals_test[1])
# Out:
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.9326 - loss: 0.3377
# Classification Accuracy:  0.930799663066864

# %% [markdown]
# ### Model Report

# %% [markdown]
# | Model | Training Accuracry | Val Accuracy | Test Accuracy |
# | --- | --- | --- | --- |
# | ResNet-50 | 99.74 | 93.36 | 93.08 |

# %% [markdown]
# ### Boundary Attack

# %%
from art.estimators.classification import TensorFlowV2Classifier
from art.attacks.evasion import BoundaryAttack

# %%
# In this assigment we will use TensorFlowV2Classifier
# It requires to specify the number of classes, input shape, and values of the inputs
classifier = TensorFlowV2Classifier(model=model, nb_classes=43, input_shape=(32, 32, 3), clip_values=(0, 255))

# %% [markdown]
# ### Boundary Untargeted Attack

# %%
# Let's use the first test images to create an adversarial example
# Plot the image and display the true and predicted class
target_image = imgs_test[111].astype(np.uint8)
print('The true class of the target image is: ' + label_names[labels_test[111]])
print("The predicted class of the target image is: ", label_names[np.argmax(classifier.predict([target_image]))])
plt.imshow(target_image)
plt.show()
# Out:
# The true class of the target image is: Stop
# The predicted class of the target image is:  Stop

# %%
t = now()

attack = BoundaryAttack(estimator=classifier, targeted=False, max_iter=0, delta=0.5, epsilon=0.3)
iter_step = 200
x_adv = None
for i in range(5):
    x_adv = attack.generate(x=np.array([target_image]), x_adv_init=x_adv)
    # print the norm of the perturbation and show the perturbed image
    print("Adversarial image at step %d." % (i * iter_step), "L2 error",
          np.linalg.norm(np.reshape(x_adv[0] - target_image, [-1])),
          "and class label %d." % np.argmax(classifier.predict(x_adv)[0]))
    print('The label is', label_names[np.argmax(classifier.predict(x_adv)[0])])
    plt.imshow(x_adv[0].astype(np.uint8))
    plt.show(block=False)

    if hasattr(attack, 'curr_delta') and hasattr(attack, 'curr_epsilon'):
        attack.max_iter = iter_step
        attack.delta = attack.curr_delta
        attack.epsilon = attack.curr_epsilon
    else:
        break

print('Attack time: %s' % (now() - t))
# Out:
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations: 0it [00:00, ?it/s]
# Adversarial image at step 0. L2 error 5825.583 and class label 2.
# The label is Speed limit (50km/h)
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:   0%|          | 0/200 [00:00<?, ?it/s]
# Adversarial image at step 200. L2 error 490.47702 and class label 2.
# The label is Speed limit (50km/h)
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:   0%|          | 0/200 [00:00<?, ?it/s]
# Adversarial image at step 400. L2 error 348.96307 and class label 2.
# The label is Speed limit (50km/h)
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:   0%|          | 0/200 [00:00<?, ?it/s]
# Adversarial image at step 600. L2 error 285.30838 and class label 2.
# The label is Speed limit (50km/h)
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:   0%|          | 0/200 [00:00<?, ?it/s]
# Adversarial image at step 800. L2 error 248.4163 and class label 2.
# The label is Speed limit (50km/h)
# Attack time: 0:06:53.064185

# %%
print("The predicted class of the target image is: ", label_names[np.argmax(classifier.predict(x_adv))])
plt.imshow(x_adv[0].astype(np.uint8))
plt.show()
# Out:
# The predicted class of the target image is:  Speed limit (50km/h)

# %%
# Show the difference between the perturbed and clean image
plt.imshow(target_image-x_adv[0], cmap='jet')
plt.colorbar()
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-25.316177..36.20408].

# %% [markdown]
# ### Untargeted Attack Report

# %% [markdown]
# The untargeted boundary attack aims to cause the model to misclassify an input without a set goal for what it will specifically be. The untargeted attack's goal is to simply degrade the accuracy of model. It operates by perturbing the input data such that it crosses the decision boundary of the model. It does this by taking an initial adversarial model which it iteratively refines to minimize perturbation while ensuring misclassification. This is achieved by leveraging gradient-based optimization or heuristic methods to find the smallest changes that push the given input over the decision boundary.

# %% [markdown]
# ### Boundary Targeted Attack

# %%
# Select a target image to create an adversarial example
target_image = imgs_test[111].astype(float)
print('The true class of the target image is: ' + label_names[labels_test[111]])
print("The predicted class of the target image is: ", label_names[np.argmax(classifier.predict([target_image]))])
plt.imshow(target_image.astype(np.uint8))
plt.show()
# Out:
# The true class of the target image is: Stop
# The predicted class of the target image is:  Stop

# %%
# Select one image from the target class as initial image
init_image = imgs_test[217]
print('The true class of the initial image is: ' + label_names[labels_test[217]])
print("The predicted class of the initial image is: ", label_names[np.argmax(classifier.predict(np.expand_dims(init_image, axis=0)))])
plt.imshow(init_image.astype(np.uint8))
plt.show()
# Out:
# The true class of the initial image is: Speed limit (80km/h)
# The predicted class of the initial image is:  Speed limit (80km/h)

# %%
# Check the class label of the initial image
print("Init image is: ", np.argmax(classifier.predict(np.array([init_image]))[0]))
# Out:
# Init image is:  5

# %%
from tensorflow.keras.utils import to_categorical

attack = BoundaryAttack(estimator=classifier, targeted=True, max_iter=0, delta=0.5, epsilon=0.3)
iter_step = 200
x_adv = np.expand_dims(init_image, axis=0)

for i in range(5):
    x_adv = attack.generate(x=np.expand_dims(target_image, axis=0), y=to_categorical([2], 11), x_adv_init=x_adv)

    # print the norm of the perturbation and show the perturbed image
    print("Adversarial image at step %d." % (i * iter_step), "L2 error",
          np.linalg.norm(np.reshape(x_adv[0] - target_image, [-1])),
          "and class label %d." % np.argmax(classifier.predict(x_adv)[0]))
    print('The label is', label_names[np.argmax(classifier.predict(x_adv)[0])])
    plt.imshow(x_adv[0].astype(np.uint8))
    plt.show(block=False)

    if hasattr(attack, 'curr_delta') and hasattr(attack, 'curr_epsilon'):
        attack.max_iter = iter_step
        attack.delta = attack.curr_delta
        attack.epsilon = attack.curr_epsilon
    else:
        break

print('Attack time: %s' % (now() - t))
# Out:
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations: 0it [00:00, ?it/s]
# Adversarial image at step 0. L2 error 5883.514115487265 and class label 2.
# The label is Speed limit (50km/h)
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:   0%|          | 0/200 [00:00<?, ?it/s]
# Adversarial image at step 200. L2 error 542.8476158153644 and class label 2.
# The label is Speed limit (50km/h)
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:   0%|          | 0/200 [00:00<?, ?it/s]
# Adversarial image at step 400. L2 error 381.01164228151964 and class label 2.
# The label is Speed limit (50km/h)
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:   0%|          | 0/200 [00:00<?, ?it/s]
# Adversarial image at step 600. L2 error 305.49907978850075 and class label 2.
# The label is Speed limit (50km/h)
# Boundary attack:   0%|          | 0/1 [00:00<?, ?it/s]
# Boundary attack - iterations:   0%|          | 0/200 [00:00<?, ?it/s]
# Adversarial image at step 800. L2 error 265.2276337223493 and class label 2.
# The label is Speed limit (50km/h)
# Attack time: 0:13:30.153254

# %%
print("The predicted class of the target image is: ", label_names[np.argmax(classifier.predict(x_adv))])
plt.imshow(x_adv[0].astype(int))
plt.show()
# Out:
# The predicted class of the target image is:  Speed limit (50km/h)

# %% [markdown]
# ### Targeted Attack Report

# %% [markdown]
# A targeted boundary attack is an attack with the goal to perturb an input image such that the model will misclassify it as a specific target class chosen by the attacker. This is the key difference between a targeted and untargeted attack as the goal is instead of simply lowering the accuracy of the model it will make it misclassify inputs into specific classes. This is achieved by iteratively modifying the input image until it is misclassified to the wanted class with as minimal perturbation as possible. The same techniques as with the untargeted, gradient based optimization or heuristic search, are used with the targeted version as well. This attack takes advantage of the model's sensitivity to small changes in the input space to get the desired result.
